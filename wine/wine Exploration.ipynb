# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv('wine.data')
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29       5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.380000  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.680000  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.800000  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.320000  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.750000  1.05
# 5    1  14.39  1.87  2.45  14.6   96  2.50  2.52  0.30  1.98   5.250000  1.02
# 6    1  14.06  2.15  2.61  17.6  121  2.60  2.51  0.31  1.25   5.050000  1.06
# 7    1  14.83  1.64  2.17  14.0   97  2.80  2.98  0.29  1.98   5.200000  1.08
# 8    1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85   7.220000  1.01
# 9    1  14.10  2.16  2.30  18.0  105  2.95  3.32  0.22  2.38   5.750000  1.25
# 10   1  14.12  1.48  2.32  16.8   95  2.20  2.43  0.26  1.57   5.000000  1.17
# ...

# %%
df.columns=['Label','Alchol','Malic Acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# %%
df.columns
# Out:
# Index(['Label', 'Alchol', 'Malic Acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
df.sample(100).plot.scatter(x = 'Alchol', y = 'Label')

# %%
df.sample(100).plot.scatter(x = 'Hue', y = 'Label')

# %%
things=df.values
Y=things[:,0]
X=things[:,1:13]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.20,random_state=1)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Label  Alchol  Malic Acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1   13.20        1.78  2.14               11.2        100
# 1        1   13.16        2.36  2.67               18.6        101
# 2        1   14.37        1.95  2.50               16.8        113
# 3        1   13.24        2.59  2.87               21.0        118
# 4        1   14.20        1.76  2.45               15.2        112
# 5        1   14.39        1.87  2.45               14.6         96
# 6        1   14.06        2.15  2.61               17.6        121
# 7        1   14.83        1.64  2.17               14.0         97
# 8        1   13.86        1.35  2.27               16.0         98
# 9        1   14.10        2.16  2.30               18.0        105
# 10       1   14.12        1.48  2.32               16.8         95
# 11       1   13.75        1.73  2.41               16.0         89
# ...

# %%
df.describe()
# Out:
#             Label      Alchol  Malic Acid         Ash  Alcalinity of ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
df.count()
# Out:
# Label                           177
# Alchol                          177
# Malic Acid                      177
# Ash                             177
# Alcalinity of ash               177
# Magnesium                       177
# Total phenols                   177
# Flavanoids                      177
# Nonflavanoid phenols            177
# Proanthocyanins                 177
# Color intensity                 177
# Hue                             177
# OD280/OD315 of diluted wines    177
# Proline                         177
# dtype: int64

# %%
df.plot(kind='box',subplots=True, layout=(3,5), sharex =False , sharey =False)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
x_train =sc.transform(X_train)
X_test =sc.transform(X_test)

# %%
#perceptron model
from sklearn.linear_model import Perceptron
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
ppn = Perceptron(max_iter = 1500, eta0 = 0.1, random_state = 1)
ppn.fit(X_train, Y_train)
y_pred = ppn.predict(X_test)
print("Accuracy score: " + str(accuracy_score(Y_test, y_pred)))
print("\nConfusion matrix: \n" + str(confusion_matrix(Y_test, y_pred)))
print("\nClassification report: \n" + str(classification_report(Y_test, y_pred)))
# Out:
# C:\Users\GT\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in Perceptron in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# Accuracy score: 0.8333333333333334
#
# Confusion matrix:
# [[12  2  0]
#  [ 2 12  2]
#  [ 0  0  6]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.86      0.86        14
#          2.0       0.86      0.75      0.80        16
#          3.0       0.75      1.00      0.86         6
#
#    micro avg       0.83      0.83      0.83        36
#    macro avg       0.82      0.87      0.84        36
# weighted avg       0.84      0.83      0.83        36

# %%
#logistic regresion
from sklearn.linear_model import LogisticRegression
ppn = LogisticRegression(C = 100, max_iter = 1500, random_state = 1)
ppn.fit(X_train, Y_train)
y_pred = ppn.predict(X_test)
print("Accuracy score: " + str(accuracy_score(Y_test, y_pred)))
print("\nConfusion matrix: \n" + str(confusion_matrix(Y_test, y_pred)))
print("\nClassification report: \n" + str(classification_report(Y_test, y_pred)))
# Out:
# C:\Users\GT\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\GT\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy score: 0.5277777777777778
#
# Confusion matrix:
# [[ 0 14  0]
#  [ 1 14  1]
#  [ 0  1  5]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        14
#          2.0       0.48      0.88      0.62        16
#          3.0       0.83      0.83      0.83         6
#
#    micro avg       0.53      0.53      0.53        36
#    macro avg       0.44      0.57      0.49        36
# weighted avg       0.35      0.53      0.42        36

# %%
#support vector machine
from sklearn.svm import SVC
ppn = SVC(C= 10000, kernel = 'rbf', degree = 3)
ppn.fit(X_train, Y_train)
y_pred = ppn.predict(X_test)
print("Accuracy score: " + str(accuracy_score(Y_test, y_pred)))
print("\nConfusion matrix: \n" + str(confusion_matrix(Y_test, y_pred)))
print("\nClassification report: \n" + str(classification_report(Y_test, y_pred)))
# Out:
# C:\Users\GT\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\GT\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy score: 0.4444444444444444
#
# Confusion matrix:
# [[ 0 14  0]
#  [ 0 16  0]
#  [ 0  6  0]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        14
#          2.0       0.44      1.00      0.62        16
#          3.0       0.00      0.00      0.00         6
#
#    micro avg       0.44      0.44      0.44        36
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-5ab168866026> in <module>
#       1 # Compare Algorithms
# ----> 2 fig = pyplot.figure()
#       3 fig.suptitle('Algorithm Comparison')
#       4 ax = fig.add_subplot(111)
#       5 pyplot.boxplot(results)
#
# NameError: name 'pyplot' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-408c4aa7a5a9> in <module>
#       1 # Standardize the dataset
#       2 pipelines = []
# ----> 3 pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR',
#       4 LogisticRegression())])))
#       5 pipelines.append(('ScaledLDA', Pipeline([('Scaler', StandardScaler()),('LDA',
#
# NameError: name 'Pipeline' is not defined
